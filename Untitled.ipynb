# %% [markdown]
# # Who is going to win the World Cup 2018?
#
# #### Hypothesis: The country who have high goals scores for and high wins will win the world Cup 2018.
#
# #### Web scrap - wikipedia qualification for world cup 2018 *all the tables*
# #### all the games win/loses/ home/away.
# #### The prediction is based on goals only !!!

# %%
import os
path="/Users/william/Documents/Documents/williamfinalproject/web scrapy/worldcup2018_draft"
os.chdir(path)

# %%
os.getcwd()
# Out:
# '/Users/william/Documents/Documents/williamfinalproject/web scrapy/worldcup2018_draft'

# %% [markdown]
# # Explore web Final webscrapying data

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
from matplotlib import pyplot as plt
wc = pd.read_csv('worldcup2018.csv', encoding='latin-1')
ww = pd.DataFrame(wc)
ww
#ww.to_csv('ww')
# Out:
#      Pos                      Team Continent Group  TotalMatch  Pld  W  D   L  \
# 0      1                     Rusia    Europe     A           0    0  0  0   0
# 1      1                    Â Iran      Asia     B         120   10  6  4   0
# 2      2             Â South Korea      Asia     F         120   10  4  3   3
# 3      3                   Â Syria      Asia   NaN         120   10  3  4   3
# 4      4              Â Uzbekistan      Asia   NaN         120   10  4  1   5
# 5      5                Â China PR      Asia   NaN         120   10  3  3   4
# 6      6                   Â Qatar      Asia   NaN         120   10  2  1   7
# 7      1                   Â Japan      Asia     H         120   10  6  2   2
# 8      2            Â Saudi Arabia      Asia     A         120   10  6  1   3
# 9      3               Â Australia      Asia     C         120   10  5  4   1
# 10     4    Â United Arab Emirates      Asia   NaN         120   10  4  1   5
# ...

# %% [markdown]
# ## Removing unknown Character

# %%
#ww.loc[ww['Continent'].isin(#value)]
ww.loc[ww['Continent']=='NorthAmerica']
ww['Team'] = ww['Team'].map(lambda x: x.lstrip('Â').rstrip('aAbBcC'))
del ww['Qualification']
ww
# Out:
#      Pos                    Team Continent Group  TotalMatch  Pld  W  D   L  \
# 0      1                    Rusi    Europe     A           0    0  0  0   0
# 1      1                    Iran      Asia     B         120   10  6  4   0
# 2      2              South Kore      Asia     F         120   10  4  3   3
# 3      3                    Syri      Asia   NaN         120   10  3  4   3
# 4      4              Uzbekistan      Asia   NaN         120   10  4  1   5
# 5      5                China PR      Asia   NaN         120   10  3  3   4
# 6      6                   Qatar      Asia   NaN         120   10  2  1   7
# 7      1                   Japan      Asia     H         120   10  6  2   2
# 8      2             Saudi Arabi      Asia     A         120   10  6  1   3
# 9      3                Australi      Asia     C         120   10  5  4   1
# 10     4    United Arab Emirates      Asia   NaN         120   10  4  1   5
# ...

# %% [markdown]
# ### South America Goals Results

# %%
#South America
SouthAmerica_Goals = ww.loc[ww['Continent'] =='SouthAmerica']

SouthAmerica_Goals
# Out:
#     Pos       Team     Continent Group  TotalMatch  Pld   W  D   L  GF  \
# 39    1     Brazil  SouthAmerica     E         180   18  12  5   1  41
# 40    2    Uruguay  SouthAmerica     A         180   18   9  4   5  32
# 41    3   Argentin  SouthAmerica     D         180   18   7  7   4  19
# 42    4    Colombi  SouthAmerica     H         180   18   7  6   5  21
# 43    5       Peru  SouthAmerica     C         180   18   7  5   6  27
# 44    6      Chile  SouthAmerica   NaN         180   18   8  2   8  26
# 45    7   Paraguay  SouthAmerica   NaN         180   18   7  3   8  19
# 46    8    Ecuador  SouthAmerica   NaN         180   18   6  2  10  26
# 47    9     Bolivi  SouthAmerica   NaN         180   18   4  2  12  16
# 48   10   Venezuel  SouthAmerica   NaN         180   18   2  6  10  19
#
#         ...        HAW HAL  HAD  HomeGoals  HomeGAgainst  HAGoals  HAAgainst  \
# 39      ...          4   1    4         26             4       15          7
# ...

# %% [markdown]
# ### North America Goals Result

# %%
#North America
NorthAmerica_Goals = ww.loc[ww['Continent'] =='NorthAmerica']
NorthAmerica_Goals_total = NorthAmerica_Goals['Pld'].sum()
NorthAmerica_Goals_total
# Out:
# 60

# %% [markdown]
# ### Africa Goals Total Result

# %%
#Africa 
Africa_Goals = ww.loc[ww['Continent'] =='Africa']
Africa_Goals_total = Africa_Goals['Pld'].sum()
Africa_Goals_total
# Out:
# 120

# %% [markdown]
# ### Asia Goals Total Result

# %%
#Asia
Asia_Goals = ww.loc[ww['Continent'] =='Asia']
Asia_Goals_total = Asia_Goals['Pld'].sum()
Asia_Goals_total
# Out:
# 120

# %% [markdown]
# ### Europe Goals Total Result

# %%
#Europe
Europe_Goals = ww.loc[ww['Continent'] =='Europe']
Europe_Goals_total = Europe_Goals['Pld'].sum()
Europe_Goals_total
# Out:
# 540

# %% [markdown]
# ### NorthAmerica Total Result

# %%
NorthAmerica_Goals = ww.loc[ww['Continent']=='NorthAmerica']

NorthAmerica_Goals
# Out:
#     Pos                  Team     Continent Group  TotalMatch  Pld  W  D  L  \
# 33    1                Mexico  NorthAmerica     F          60   10  6  3  1
# 34    2              Costa Ri  NorthAmerica     E          60   10  4  4  2
# 35    3                 Panam  NorthAmerica     G          60   10  3  4  3
# 36    4              Honduras  NorthAmerica   NaN          60   10  3  4  3
# 37    5         United States  NorthAmerica   NaN          60   10  3  3  4
# 38    6   Trinidad and Tobago  NorthAmerica   NaN          60   10  2  0  8
#
#     GF      ...        HAW HAL  HAD  HomeGoals  HomeGAgainst  HAGoals  \
# 33  16      ...          2   1    2         10             2        6
# 34  14      ...          2   2    1          8             3        6
# 35   9      ...          1   3    1          8             5        1
# 36  13      ...          1   2    2          8             6        5
# 37  17      ...          0   2    3         12             4        4
# ...

# %% [markdown]
# ## Convert to Numeric all number

# %%
from functools import partial
ww.dtypes

ww = ww.convert_objects(convert_numeric=True)
# Out:
# /Users/william/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   after removing the cwd from sys.path.

# %% [markdown]
# ## Change Columns Name

# %%
ww.columns = ['Position', 'Team','Continent','Group', 'Total_NumGame','Number_Games','Wins', 'Draw', 'Losses', 'Goal_For', 'Goal_Against', 'Goal_Difference', 'Point', 'HomeWins', 'HomeLosses','HomeDraw', 'HomeAway_Win','HomeAway_loss', 'HomeAway_draw', 'Home_Goals','Home_Goals_Against','HomeAway_Goals', 'HomeAway_Goals_Against','Ave_TotalGameWin_Team', 'Ave_GameWinHome', 'Ave_GameWinAway']

# %% [markdown]
# ### Missing Values

# %%
ww.sort_values('Group')
ww.isnull()
np.sum(ww.isnull(), axis=1)
team_elimination = ww.isnull().any(axis=1)
ww.isnull().sum(axis=0)
# Out:
# Position                   0
# Team                       0
# Continent                  0
# Group                     71
# Total_NumGame              0
# Number_Games               0
# Wins                       0
# Draw                       0
# Losses                     0
# Goal_For                   0
# Goal_Against               0
# Goal_Difference           44
# Point                      0
# HomeWins                   0
# HomeLosses                 0
# HomeDraw                   0
# HomeAway_Win               0
# HomeAway_loss              0
# HomeAway_draw              0
# Home_Goals                 0
# Home_Goals_Against         0
# HomeAway_Goals             0
# HomeAway_Goals_Against     0
# Ave_TotalGameWin_Team      1
# Ave_GameWinHome            1
# Ave_GameWinAway            1
# dtype: int64

# %%
missing_row = ww.isnull().sum(axis=1)>0
#ww=ww[ww['Wins']>7]
#ww['Wins']=ww['Losses'] !=0
ww.loc[missing_row]
# Out:
#      Position                    Team     Continent Group  Total_NumGame  \
# 3           3                    Syri          Asia   NaN            120
# 4           4              Uzbekistan          Asia   NaN            120
# 5           5                China PR          Asia   NaN            120
# 6           6                   Qatar          Asia   NaN            120
# 10          4    United Arab Emirates          Asia   NaN            120
# 11          5                    Iraq          Asia   NaN            120
# 12          6                Thailand          Asia   NaN            120
# 14          2                DR Congo        Africa   NaN            120
# 15          3                    Liby        Africa   NaN            120
# 16          4                   Guine        Africa   NaN            120
# 18          2                   Zambi        Africa   NaN            120
# 19          3                Cameroon        Africa   NaN            120
# ...

# %% [markdown]
# ### Qualify_Country list

# %%
qualify_country =ww.dropna(axis=0, how='any')
qualify_country.columns = qualify_country.columns.str.upper()
qualify_country.sort_values('GROUP')
# Out:
#     POSITION            TEAM     CONTINENT GROUP  TOTAL_NUMGAME  NUMBER_GAMES  \
# 0          1            Rusi        Europe     A              0             0
# 8          2     Saudi Arabi          Asia     A            120            10
# 29         1           Egypt        Africa     A            120             6
# 40         2         Uruguay  SouthAmerica     A            180            18
# 1          1            Iran          Asia     B            120            10
# 85         1           Spain        Europe     B            540            10
# 55         1        Portugal        Europe     B            540            10
# 21         1         Morocco        Africa     B            120             6
# 74         2         Denmark        Europe     C            540            10
# 9          3        Australi          Asia     C            120            10
# 49         1          France        Europe     C            540            10
# ...

# %% [markdown]
# ### Creating Ratio Column win

# %%
qualify_country['RATION_WIN'] = qualify_country['WINS']/qualify_country['NUMBER_GAMES']
qualify_country
# Out:
# /Users/william/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#     POSITION            TEAM     CONTINENT GROUP  TOTAL_NUMGAME  NUMBER_GAMES  \
# 0          1            Rusi        Europe     A              0             0
# 1          1            Iran          Asia     B            120            10
# 2          2      South Kore          Asia     F            120            10
# 7          1           Japan          Asia     H            120            10
# 8          2     Saudi Arabi          Asia     A            120            10
# 9          3        Australi          Asia     C            120            10
# ...

# %% [markdown]
# ### Groupby

# %%
group_continent = qualify_country.groupby('CONTINENT')

# %%
group_A = qualify_country.groupby('GROUP')

# %%
for item in group_continent:
    print(item)
# Out:
# ('Africa',     POSITION      TEAM CONTINENT GROUP  TOTAL_NUMGAME  NUMBER_GAMES  WINS  \
# 13         1    Tunisi    Africa     G            120             6     4
# 17         1    Nigeri    Africa     D            120             6     4
# 21         1   Morocco    Africa     B            120             6     3
# 25         1   Senegal    Africa     H            120             6     4
# 29         1     Egypt    Africa     A            120             6     4
#
#     DRAW  LOSSES  GOAL_FOR     ...      HOMEAWAY_LOSS  HOMEAWAY_DRAW  \
# 13     2       0        11     ...                  1              1
# 17     1       1        11     ...                  1              1
# 21     3       0        11     ...                  0              2
# 25     2       0        10     ...                  0              1
# 29     1       1         8     ...                  1              1
#
#     HOME_GOALS  HOME_GOALS_AGAINST  HOMEAWAY_GOALS  HOMEAWAY_GOALS_AGAINST  \
# ...

# %% [markdown]
# ## Divide by Group

# %%
for key, values in group_continent:
    print(key)
    print('-'*50)
    print(values)
# Out:
# Africa
# --------------------------------------------------
#     POSITION      TEAM CONTINENT GROUP  TOTAL_NUMGAME  NUMBER_GAMES  WINS  \
# 13         1    Tunisi    Africa     G            120             6     4
# 17         1    Nigeri    Africa     D            120             6     4
# 21         1   Morocco    Africa     B            120             6     3
# 25         1   Senegal    Africa     H            120             6     4
# 29         1     Egypt    Africa     A            120             6     4
#
#     DRAW  LOSSES  GOAL_FOR     ...      HOMEAWAY_LOSS  HOMEAWAY_DRAW  \
# 13     2       0        11     ...                  1              1
# 17     1       1        11     ...                  1              1
# 21     3       0        11     ...                  0              2
# 25     2       0        10     ...                  0              1
# 29     1       1         8     ...                  1              1
#
# ...

# %% [markdown]
# ### Count total countries 31 + Rusia

# %%
group_continent.size()
#qualify_country['TEAM'].value_counts()
# Out:
# CONTINENT
# Africa           5
# Asia             5
# Europe          14
# NorthAmerica     2
# SouthAmerica     5
# dtype: int64

# %% [markdown]
# ### Mean value for Continet

# %%
# Continent - having a higher number for Wins and Goals have high probability of countires to win the WorldCup 
group_continent.mean()
# Out:
#               POSITION  TOTAL_NUMGAME  NUMBER_GAMES      WINS      DRAW  \
# CONTINENT
# Africa        1.000000     120.000000      6.000000  3.800000  1.800000
# Asia          1.800000     120.000000     10.000000  5.400000  2.800000
# Europe        1.285714     501.428571      9.285714  7.142857  1.142857
# NorthAmerica  1.500000      60.000000     10.000000  5.000000  3.500000
# SouthAmerica  3.000000     180.000000     18.000000  8.400000  5.400000
#
#               LOSSES   GOAL_FOR  GOAL_AGAINST  GOAL_DIFFERENCE      POINT  \
# CONTINENT
# Africa           0.4  10.200000      3.400000         6.800000  13.200000
# Asia             1.8  14.200000      8.000000         6.200000  19.000000
# Europe           1.0  24.142857      6.071429        18.071429  22.571429
# NorthAmerica     1.5  15.000000      7.500000         7.500000  18.500000
# SouthAmerica     4.2  28.000000     18.400000         9.600000  30.600000
#
# ...

# %%
#group.agg(['count', 'sum', 'min', 'max', 'mean', 'std'])

# %% [markdown]
# # Graph

# %% [markdown]
# #### There are 3 countries who has 40 goal above

# %%
#plt.hist(qualify_country['GOAL_FOR'])
#WINNER = plt.hist(qualify_country['WiNS'])


import seaborn as sns
Goals = qualify_country['GOAL_FOR']
Goals.plot.hist()
plt.xlabel('Total Goals')
plt.ylabel('Number of countries')
plt.title('Histogram of Goals', fontsize = 22)
# Out:
# Text(0.5,1,'Histogram of Goals')

# %% [markdown]
# #### Goals against vs Goal for
# ##### Interesting in seeing right size of the graph where I am going to focus on

# %%
scatter_qualify = qualify_country[['GOAL_FOR', 'GOAL_AGAINST']]
scatter_qualify = scatter_qualify.loc[scatter_qualify.apply(lambda x: np.abs(x - x.mean()) / x.std() < 3).all(axis=1)]

scatter_qualify.plot.scatter(x='GOAL_FOR', y='GOAL_AGAINST')

# %%
#score_df = qualify_country[['WINS', 'GOAL_DIFFERENCE']]
#score_df.plot.scatter('WINS', 'GOAL_DIFFERENCE')

# %%
qualify_country.dtypes
# Out:
# POSITION                    int64
# TEAM                       object
# CONTINENT                  object
# GROUP                      object
# TOTAL_NUMGAME               int64
# NUMBER_GAMES                int64
# WINS                        int64
# DRAW                        int64
# LOSSES                      int64
# GOAL_FOR                    int64
# GOAL_AGAINST                int64
# GOAL_DIFFERENCE           float64
# POINT                       int64
# HOMEWINS                    int64
# HOMELOSSES                  int64
# HOMEDRAW                    int64
# HOMEAWAY_WIN                int64
# HOMEAWAY_LOSS               int64
# HOMEAWAY_DRAW               int64
# HOME_GOALS                  int64
# HOME_GOALS_AGAINST          int64
# HOMEAWAY_GOALS              int64
# HOMEAWAY_GOALS_AGAINST      int64
# AVE_TOTALGAMEWIN_TEAM     float64
# AVE_GAMEWINHOME           float64
# AVE_GAMEWINAWAY           float64
# RATION_WIN                float64
# dtype: object

# %%
from functools import partial
qualify_country.dtypes
#qualify_country = qualify_country.apply(partial(pd.to_numeric, error='coerce')).info()

#qualify_country['GD'] = qualify_country["GD"].to_numeric()

#qualify_country = qualify_country.apply(to_numeric)
qualify_country = qualify_country.convert_objects(convert_numeric=True)
# Out:
# /Users/william/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.

# %% [markdown]
# #### WIns vs Goal For - Countries who has higher win,its have higher goal scores

# %%
qualify_country.plot.scatter('WINS', 'GOAL_FOR')

# %% [markdown]
# #### Losses vs Goal Against - higher goals against have higher losses

# %%
qualify_country.plot.scatter('LOSSES', 'GOAL_AGAINST')

# %% [markdown]
# #### German, Belgium, Brazil, Spain - hve high win

# %%
#%matplotlib inline
#from matplotlib import pyplot as plt
#plt.figure(figsize=(12,6))
#qualify_country.groupby('Country')['GOAL_FOR'].mean().sort_values(ascending=False).plot(kind='bar',color='b')

# %% [markdown]
# ####

# %%
#top_winner = qualify_country.groupby('TEAM').filter(lambda x:x.shape[1]>8)
#top_winner.groupby('TEAM')['WINS'].median().sort_values(ascending=False).plot(kind='bar',color='b')

import seaborn as sns
sns.kdeplot(qualify_country['GOAL_AGAINST'], shade=True, label='Country of Goal scores')
# Out:
# /Users/william/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(qualify_country['WINS'])
# Out:
# /Users/william/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Graph showed - Countries from Europe and SouthAmerica have high chance to win

# %%
sns.lmplot('WINS', 'GOAL_FOR', qualify_country, hue='CONTINENT', palette="Set2")
# Out:
# /Users/william/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
for item in group_A:
    print(item)
# Out:
# ('A',     POSITION          TEAM     CONTINENT GROUP  TOTAL_NUMGAME  NUMBER_GAMES  \
# 0          1          Rusi        Europe     A              0             0
# 8          2   Saudi Arabi          Asia     A            120            10
# 29         1         Egypt        Africa     A            120             6
# 40         2       Uruguay  SouthAmerica     A            180            18
#
#     WINS  DRAW  LOSSES  GOAL_FOR     ...      HOMEAWAY_LOSS  HOMEAWAY_DRAW  \
# 0      0     0       0         0     ...                  0              0
# 8      6     1       3        17     ...                  3              0
# 29     4     1       1         8     ...                  1              1
# 40     9     4       5        32     ...                  4              3
#
#     HOME_GOALS  HOME_GOALS_AGAINST  HOMEAWAY_GOALS  HOMEAWAY_GOALS_AGAINST  \
# 0            0                   0               0                       0
# ...

# %%
for key, values in group_A:
    print(key)
    print('-'*50)
    print(values)
# Out:
# A
# --------------------------------------------------
#     POSITION          TEAM     CONTINENT GROUP  TOTAL_NUMGAME  NUMBER_GAMES  \
# 0          1          Rusi        Europe     A              0             0
# 8          2   Saudi Arabi          Asia     A            120            10
# 29         1         Egypt        Africa     A            120             6
# 40         2       Uruguay  SouthAmerica     A            180            18
#
#     WINS  DRAW  LOSSES  GOAL_FOR     ...      HOMEAWAY_LOSS  HOMEAWAY_DRAW  \
# 0      0     0       0         0     ...                  0              0
# 8      6     1       3        17     ...                  3              0
# 29     4     1       1         8     ...                  1              1
# 40     9     4       5        32     ...                  4              3
#
#     HOME_GOALS  HOME_GOALS_AGAINST  HOMEAWAY_GOALS  HOMEAWAY_GOALS_AGAINST  \
# 0            0                   0               0                       0
# ...

# %% [markdown]
# ### Qualify teams

# %%
group_A.size()
# Out:
# GROUP
# A    4
# B    4
# C    4
# D    4
# E    4
# F    4
# G    3
# H    4
# dtype: int64

# %%
qualify_country
# Out:
#     POSITION            TEAM     CONTINENT GROUP  TOTAL_NUMGAME  NUMBER_GAMES  \
# 0          1            Rusi        Europe     A              0             0
# 1          1            Iran          Asia     B            120            10
# 2          2      South Kore          Asia     F            120            10
# 7          1           Japan          Asia     H            120            10
# 8          2     Saudi Arabi          Asia     A            120            10
# 9          3        Australi          Asia     C            120            10
# 13         1          Tunisi        Africa     G            120             6
# 17         1          Nigeri        Africa     D            120             6
# 21         1         Morocco        Africa     B            120             6
# 25         1         Senegal        Africa     H            120             6
# 29         1           Egypt        Africa     A            120             6
# ...

# %% [markdown]
# ### Goals Home and Away

# %%
################### Europe ##############
#Score Home
Europe_Goals = ww.loc[ww['Continent'] =='Europe']
ETGH = Europe_Goals['Home_Goals'].sum()
ETGH #(Europe Total Goal at Home)

#Score Away
Europe_Goals = ww.loc[ww['Continent'] =='Europe']
ETGA = Europe_Goals['HomeAway_Goals'].sum()
#ETGA #(Europe Total Goal at Away)
####################### ASIA ##################################
#AsiTGH #(Asia Total Goal at Home)
Asia_Goals = ww.loc[ww['Continent'] =='Asia']
AsiTGH = Asia_Goals['Home_Goals'].sum()
#AsiTGH #(Europe Total Goal at Home)
Asia_Goals = ww.loc[ww['Continent'] =='Asia']
AsiTGA = Asia_Goals['HomeAway_Goals'].sum()
#AsiTGA
###################### Africa ##################################
Africa_Goals = ww.loc[ww['Continent'] =='Africa']
AfTGH = Africa_Goals['Home_Goals'].sum()
AfTGH
#AsiTGH #(Europe Total Goal at Home)
Africa_Goals = ww.loc[ww['Continent'] =='Africa']
AfTGA = Africa_Goals['HomeAway_Goals'].sum()
#AfTGA

####################South America ###########################
SouthAm_Goals = ww.loc[ww['Continent'] =='SouthAmerica']
SATGH = SouthAm_Goals['Home_Goals'].sum()
#SATGH
#AsiTGH #(Europe Total Goal at Home)
SouthAm_Goals = ww.loc[ww['Continent'] =='SouthAmerica']
SATGA = SouthAm_Goals['HomeAway_Goals'].sum()
#SATGA
##################### North America ##########################
NorthAm_Goals = ww.loc[ww['Continent'] =='NorthAmerica']
NATGH = SouthAm_Goals['Home_Goals'].sum()
#NATGH
#AsiTGH #(Europe Total Goal at Home)
NorthAm_Goals = ww.loc[ww['Continent'] =='NorthAmerica']
NATGA = NorthAm_Goals['HomeAway_Goals'].sum()
#NATGA

# %%
#Attack strength and Defense Strength for each Team(country)
#calculation for Poisson Distribution
#ATTACK Strength
# 1- total Home goal score/total # of Home game for each continent

#qualify_country.loc['Preliminary_Total_GoalsHome'] = (ETGH / 270)
Preliminary_Total_GoalsHome = (ETGH / 270)
#Preliminary_Total_GoalsAway= ETGA / 270
#Preliminary_Total_GoalsAway

#Average number of goals scored at home = 1.68
#Average number of goals scored away = 1.26

#Defence Strength
#Average number of goals conceded at home = 1.26
#Average number of goals conceded away = 1.68


#Europe_Goals = ww.loc[ww['Continent'] =='Europe']
#Europe_Goals_total = Europe_Goals['Number_Games'].sum()
#Europe_Goals_total

# %%
# 2- total Home away goal score/total# of Home game
#German 
#total goal /total number of home games
TPH = qualify_country['HOME_GOALS']/(qualify_country['NUMBER_GAMES']/2)
TPH
#Defense Strength NUMBER_GAMES
# 3- total Home away score/total # of Away game
# 4- total Home score / total # of Home game
TPA = qualify_country['HOMEAWAY_GOALS']/(qualify_country['NUMBER_GAMES']/2)
TPA
# Team Attack Strength
# 5 - (total number of Home goal score / total # of home game)/ #1

# Team Defense
# 6 - (total number of home away conceded score/ total # home way)/ #3

# Prediction (Attack)
# #5 x #6 x #1

#Prediction (Defense)
#
# Out:
# 0          NaN
# 1     0.400000
# 2     0.400000
# 7     1.200000
# 8     1.800000
# 9     1.200000
# 13    2.333333
# 17    1.000000
# 21    0.666667
# 25    2.000000
# 29    1.000000
# 33    1.200000
# 34    1.200000
# 39    1.666667
# 40    1.222222
# 41    1.111111
# 42    1.000000
# 43    1.333333
# 49    1.200000
# 50    1.600000
# 55    2.400000
# 56    2.000000
# 61    4.000000
# 67    2.000000
# 73    2.600000
# 74    2.000000
# 79    1.600000
# 85    2.800000
# 91    3.400000
# 97    1.200000
# 98    1.800000
# dtype: float64

# %% [markdown]
# # Calculation
# ### Poisson Distribution
# ##### Suppose we conduct a Poisson experiment, in which the average number of successes within a given region is μ. Then, the Poisson probability is: P(x; μ) = (e-μ) (μx) / x! where x is the actual number of successes that result from the experiment, and e is approximately equal to 2.71828
# #### ![image.png](attachment:image.png)

# %% [markdown]
# ### Scikit Learn

# %%
import pandas as pd
import xgboost as xgb
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from IPython.display import display
from pandas.tools.plotting import scatter_matrix

# %%
display(qualify_country)
# Out:
#     POSITION            TEAM     CONTINENT GROUP  TOTAL_NUMGAME  NUMBER_GAMES  \
# 0          1            Rusi        Europe     A              0             0
# 1          1            Iran          Asia     B            120            10
# 2          2      South Kore          Asia     F            120            10
# 7          1           Japan          Asia     H            120            10
# 8          2     Saudi Arabi          Asia     A            120            10
# 9          3        Australi          Asia     C            120            10
# 13         1          Tunisi        Africa     G            120             6
# 17         1          Nigeri        Africa     D            120             6
# 21         1         Morocco        Africa     B            120             6
# 25         1         Senegal        Africa     H            120             6
# 29         1           Egypt        Africa     A            120             6
# ...

# %%
qualify_country.columns
# Out:
# Index(['POSITION', 'TEAM', 'CONTINENT', 'GROUP', 'TOTAL_NUMGAME',
#        'NUMBER_GAMES', 'WINS', 'DRAW', 'LOSSES', 'GOAL_FOR', 'GOAL_AGAINST',
#        'GOAL_DIFFERENCE', 'POINT', 'HOMEWINS', 'HOMELOSSES', 'HOMEDRAW',
#        'HOMEAWAY_WIN', 'HOMEAWAY_LOSS', 'HOMEAWAY_DRAW', 'HOME_GOALS',
#        'HOME_GOALS_AGAINST', 'HOMEAWAY_GOALS', 'HOMEAWAY_GOALS_AGAINST',
#        'AVE_TOTALGAMEWIN_TEAM', 'AVE_GAMEWINHOME', 'AVE_GAMEWINAWAY',
#        'RATION_WIN'],
#       dtype='object')

# %%
qualify_country.shape
graph = scatter_matrix(qualify_country[['WINS','DRAW','LOSSES','GOAL_FOR', 'GOAL_AGAINST','POINT']], figsize=(10,10)),

#n_featuers = qualify_country.shape[1]-1

#n_homewins = len(qualify_country(qualify_country.WINS == 'H'))

#win_rate = (float(n_homewins) / (n_matches))
# Out:
# /Users/william/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.

# %% [markdown]
# ### classification

# %%
X_all = qualify_country.drop(['WINS'],1)
y_all = qualify_country['WINS']

#Standardisng the data 
from sklearn.preprocessing import scale

cols = [['AVE_TOTALGAMEWIN_TEAM', 'AVE_GAMEWINHOME', 'AVE_GAMEWINAWAY', 'RATION_WIN']]
for col in cols:
    X_all[col] = scale(X_all[col])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-b6303f92bc67> in <module>()
#       7 cols = [['AVE_TOTALGAMEWIN_TEAM', 'AVE_GAMEWINHOME', 'AVE_GAMEWINAWAY', 'RATION_WIN']]
#       8 for col in cols:
# ----> 9     X_all[col] = scale(X_all[col])
#      10
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py in scale(X, axis, with_mean, with_std, copy)
#     131     X = check_array(X, accept_sparse='csc', copy=copy, ensure_2d=False,
#     132                     warn_on_dtype=True, estimator='the scale function',
# --> 133                     dtype=FLOAT_DTYPES)
#     134     if sparse.issparse(X):
#     135         if with_mean:
#
# ...

# %%
qualify_country[qualify_country['TEAM'].str.contains('German')]
# Out:
#     POSITION      TEAM CONTINENT GROUP  TOTAL_NUMGAME  NUMBER_GAMES  WINS  \
# 61         1   Germany    Europe     F            540            10    10
#
#     DRAW  LOSSES  GOAL_FOR     ...      HOMEAWAY_LOSS  HOMEAWAY_DRAW  \
# 61     0       0        43     ...                  0              0
#
#     HOME_GOALS  HOME_GOALS_AGAINST  HOMEAWAY_GOALS  HOMEAWAY_GOALS_AGAINST  \
# 61          23                   1              20                       3
#
#     AVE_TOTALGAMEWIN_TEAM  AVE_GAMEWINHOME  AVE_GAMEWINAWAY  RATION_WIN
# 61                    0.6              0.8              0.4         1.0
#
# [1 rows x 27 columns]
